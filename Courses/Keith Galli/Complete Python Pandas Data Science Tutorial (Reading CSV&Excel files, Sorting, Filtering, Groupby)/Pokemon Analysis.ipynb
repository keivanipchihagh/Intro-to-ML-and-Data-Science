# %% [markdown]
# # Pokemon Analysis

# %%
# Imports
import pandas as pd
import re

# %%
# load Data

# csv
df = pd.read_csv('datasets/pokemon_data.csv')
df.head()

# xlsx
# df_xlsx = pd.read_excel('datasets/pokemon_data.xlsx')
# df_xlsx.head()

# txt
# df_txt = pd.read_csv('datasets/pokemon_data.txt', delimiter = '\t')
# df_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Get columns
df.columns

# Get by column
df[['Name', 'HP', 'Attack']]

# Get by row
df.iloc[1:3]

# Get by row & column
df.iloc[2, 1]

# Iteration
# for index, row in df.iterrows():
#     print(index, row['Name'])
    
# Get by condition
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Describing data
df.describe()

# Sorting data
df.sort_values(by = ['HP', 'Type 1'], ascending = [True, False])
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 487  439   Mime Jr.  Psychic  Fairy   20      25       45       70       90
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# ...

# %%
# Manipulating data

# df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df['Total'] = df.iloc[:, 4:10].sum(axis = 1)

df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525

# %%
# Drop columns
df.drop(columns = ['Total'], inplace = True)
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
# Reposition columns
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:-1]]
df.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
# Save the dataframe

# As csv
df.to_csv('datasets/modified_pokemon_data.csv', index = False)

# Ax Xlsx
df.to_excel('datasets/modified_pokemon_data.xlsx', index = False)

# As txt
df.to_csv('datasets/modified_pokemon_data.txt', index = False, sep = '\t')

# %%
# Filter data
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 652  591              Amoonguss  Grass  Poison    464  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 50       110       90     50           1      False
# 77       100       70     70           1      False
# 652       85       80     30           5      False

# %%
# Filter with regex
df.loc[~df['Name'].str.contains('Mega')]

df.loc[df['Type 1'].str.contains('fire|grass', regex = True, flags = re.I)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Conditional Changes
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion   Flamer  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df.loc[df['Total'] > 500, ['Type 1', 'HP']] = ['Fire', '45']
df.tail()
# Out:
#        #                 Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie   Fire  Fairy    600  45     100      150
# 796  719  DiancieMega Diancie   Fire  Fairy    700  45     160      110
# 797  720  HoopaHoopa Confined   Fire  Ghost    600  45     110       60
# 798  720   HoopaHoopa Unbound   Fire   Dark    680  45     160       60
# 799  721            Volcanion   Fire  Water    600  45     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df = pd.read_csv('datasets/pokemon_data.csv')

# %%
# Group by
df.groupby('Type 1').mean().sort_values(by = 'Defense', ascending = False)

df.groupby(['Type 1', 'Type 2']).count()
# Out:
#                   #  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric   2     2   2       2        2        2        2      2
#        Fighting   2     2   2       2        2        2        2      2
#        Fire       2     2   2       2        2        2        2      2
#        Flying    14    14  14      14       14       14       14     14
#        Ghost      1     1   1       1        1        1        1      1
# ...              ..   ...  ..     ...      ...      ...      ...    ...
# Water  Ice        3     3   3       3        3        3        3      3
#        Poison     3     3   3       3        3        3        3      3
#        Psychic    5     5   5       5        5        5        5      5
#        Rock       4     4   4       4        4        4        4      4
#        Steel      1     1   1       1        1        1        1      1
#
#                  Generation  Legendary
# Type 1 Type 2
# ...

# %%
# Working with large data (20GB and more)
for chunk in pd.read_csv('datasets/pokemon_data.csv', chunksize = 50):
    print(chunk.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
#      #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50  45  Vileplume  Grass  Poison  75      80       85      110       90
# 51  46      Paras    Bug   Grass  35      70       55       45       55
# 52  47   Parasect    Bug   Grass  60      95       80       60       80
#
#     Speed  Generation  Legendary
# 50     50           1      False
# 51     25           1      False
# 52     30           1      False
#       #               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# ...
